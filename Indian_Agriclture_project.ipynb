# %% [markdown]
# # **`Indian Agriclture project`**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('agroData.csv')
df
# Out:
#                  State            District             Market  \
# 0     Himachal Pradesh             Sirmore       Paonta Sahib
# 1     Himachal Pradesh             Sirmore       Paonta Sahib
# 2     Himachal Pradesh             Sirmore       Paonta Sahib
# 3     Himachal Pradesh             Sirmore       Paonta Sahib
# 4     Himachal Pradesh             Sirmore       Paonta Sahib
# ...                ...                 ...                ...
# 9913       West Bengal            Puruliya            Purulia
# 9914       West Bengal            Puruliya            Purulia
# 9915       West Bengal  Sounth 24 Parganas  Baruipur(Canning)
# 9916       West Bengal  Sounth 24 Parganas  Baruipur(Canning)
# 9917       West Bengal      Uttar Dinajpur           Islampur
#
#                     Commodity    Variety  Grade Arrival_Date  Min_x0020_Price  \
# 0                      Banana      Other    NaN   23/02/2023           5000.0
# 1                    Capsicum      Other    NaN   23/02/2023           2500.0
# 2     French Beans (Frasbean)      Other    NaN   23/02/2023           4000.0
# 3                      Kinnow      Other    NaN   23/02/2023           4500.0
# 4             Leafy Vegetable      Other    NaN   23/02/2023           1000.0
# ...                       ...        ...    ...          ...              ...
# 9913                Moath Dal  Moath Dal    NaN   23/02/2023           9000.0
# 9914                   Potato      Jyoti    NaN   23/02/2023            580.0
# 9915                  Brinjal    Brinjal    NaN   23/02/2023           3000.0
# 9916                  Cabbage    Cabbage    NaN   23/02/2023            400.0
# 9917                   Potato     F.A.Q.    NaN   23/02/2023            500.0
#
#       Max_x0020_Price  Modal_x0020_Price
# 0              6000.0             5500.0
# 1              4000.0             3000.0
# 2              5500.0             5000.0
# 3              6000.0             5000.0
# 4                 NaN             1000.0
# ...               ...                ...
# 9913           9200.0             9100.0
# 9914            620.0              600.0
# 9915           3200.0             3100.0
# 9916            600.0              500.0
# 9917            600.0              550.0
#
# [9918 rows x 10 columns]

# %%
df.shape
# Out:
# (9918, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9918 entries, 0 to 9917
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   State              9918 non-null   object
#  1   District           9918 non-null   object
#  2   Market             9918 non-null   object
#  3   Commodity          9918 non-null   object
#  4   Variety            9918 non-null   object
#  5   Grade              0 non-null      float64
#  6   Arrival_Date       9918 non-null   object
#  7   Min_x0020_Price    9910 non-null   float64
#  8   Max_x0020_Price    9878 non-null   float64
#  9   Modal_x0020_Price  9918 non-null   float64
# dtypes: float64(4), object(6)
# memory usage: 775.0+ KB

# %%
df.isnull().sum()/len(df)*100
# Out:
# State                  0.000000
# District               0.000000
# Market                 0.000000
# Commodity              0.000000
# Variety                0.000000
# Grade                100.000000
# Arrival_Date           0.000000
# Min_x0020_Price        0.080661
# Max_x0020_Price        0.403307
# Modal_x0020_Price      0.000000
# dtype: float64

# %%
df.drop('Grade',axis=1,inplace=True)

# %%
df.head()
# Out:
#               State District        Market                Commodity Variety  \
# 0  Himachal Pradesh  Sirmore  Paonta Sahib                   Banana   Other
# 1  Himachal Pradesh  Sirmore  Paonta Sahib                 Capsicum   Other
# 2  Himachal Pradesh  Sirmore  Paonta Sahib  French Beans (Frasbean)   Other
# 3  Himachal Pradesh  Sirmore  Paonta Sahib                   Kinnow   Other
# 4  Himachal Pradesh  Sirmore  Paonta Sahib          Leafy Vegetable   Other
#
#   Arrival_Date  Min_x0020_Price  Max_x0020_Price  Modal_x0020_Price
# 0   23/02/2023           5000.0           6000.0             5500.0
# 1   23/02/2023           2500.0           4000.0             3000.0
# 2   23/02/2023           4000.0           5500.0             5000.0
# 3   23/02/2023           4500.0           6000.0             5000.0
# 4   23/02/2023           1000.0              NaN             1000.0

# %%
print('Average Value Max Price =',df['Max_x0020_Price'].mean())
print('Average Value Min Price =',df['Min_x0020_Price'].mean())
# Out:
# Average Value Max Price = 4428.146715934399
# Average Value Min Price = 3762.558096871847

# %%
df.isnull().sum()
# Out:
# State                 0
# District              0
# Market                0
# Commodity             0
# Variety               0
# Arrival_Date          0
# Min_x0020_Price       8
# Max_x0020_Price      40
# Modal_x0020_Price     0
# dtype: int64

# %%
df['Max_x0020_Price'].fillna(df['Max_x0020_Price'].mean(),inplace=True)
df['Min_x0020_Price'].fillna(df['Min_x0020_Price'].mean(),inplace=True)

# %%
df.isnull().sum()/len(df)*100
# Out:
# State                0.0
# District             0.0
# Market               0.0
# Commodity            0.0
# Variety              0.0
# Arrival_Date         0.0
# Min_x0020_Price      0.0
# Max_x0020_Price      0.0
# Modal_x0020_Price    0.0
# dtype: float64

# %%
print('Total Duplicated Values in the dataset =',df.duplicated().sum())
# Out:
# Total Duplicated Values in the dataset = 0

# %%
df.describe()
# Out:
#        Min_x0020_Price  Max_x0020_Price  Modal_x0020_Price
# count      9918.000000      9918.000000        9918.000000
# mean       3762.558097      4428.146716        4114.652279
# std       11533.084132     13937.457242       12741.969488
# min           1.000000         2.000000           2.000000
# 25%        1200.000000      1500.000000        1340.000000
# 50%        2300.000000      2800.000000        2500.000000
# 75%        4400.000000      5000.000000        4835.250000
# max      800000.000000   1000000.000000      900000.000000

# %%
sns.heatmap(df.corr(),annot=True,linewidths=1)
plt.title('The Correlation HeatMap')
plt.plot()
# Out:
# []

# %% [markdown]
# # **Explore Data Analysis**

# %% [markdown]
# # **Questions Asked from the Data**

# %% [markdown]
# *   To find the unique states in the data, you can use the unique() function on the 'State' column
#
# *   To visualize the usage of states in the data, you can use the value_counts() function on the 'State' column and plot it as a bar chart
# *   To visualize the top 10 districts in the data, you can use the value_counts() function on the 'District' column, retrieve the top 10 districts, and plot them as a bar chart.
# *    To find the market that generated the most revenue, you can calculate the total revenue for each market and plot it as a pie chart.
# *   To visualize the distribution of maximum, minimum, and modal prices, you can create a histogram for each using the hist() function.
# *   To analyze the relationship between the minimum and modal prices, you can create a scatter plot using the plot() function:
# *   To create a data frame for visualizing the average prices of commodities along with the minimum, maximum, and modal prices, you can use the groupby() function and aggregate the data
# *   To visualize the percentage of the top 10 commodities in the data, you can calculate the percentage and plot it as a pie chart.
# *   To find the revenue generated by each state and visualize it as a bar chart, you can multiply the minimum and maximum prices and plot the bar chart.

# %%
df.head()
# Out:
#               State District        Market                Commodity Variety  \
# 0  Himachal Pradesh  Sirmore  Paonta Sahib                   Banana   Other
# 1  Himachal Pradesh  Sirmore  Paonta Sahib                 Capsicum   Other
# 2  Himachal Pradesh  Sirmore  Paonta Sahib  French Beans (Frasbean)   Other
# 3  Himachal Pradesh  Sirmore  Paonta Sahib                   Kinnow   Other
# 4  Himachal Pradesh  Sirmore  Paonta Sahib          Leafy Vegetable   Other
#
#   Arrival_Date  Min_x0020_Price  Max_x0020_Price  Modal_x0020_Price
# 0   23/02/2023           5000.0      6000.000000             5500.0
# 1   23/02/2023           2500.0      4000.000000             3000.0
# 2   23/02/2023           4000.0      5500.000000             5000.0
# 3   23/02/2023           4500.0      6000.000000             5000.0
# 4   23/02/2023           1000.0      4428.146716             1000.0

# %%
#To find the unique states in the data, you can use the unique() function on the 'State' column.

print('Unique States in Dataset are =',df['State'].unique())
print('\nMost Dominating State =',df['State'].value_counts().idxmax())
print('\nLeast Dominating State =',df['State'].value_counts().idxmin())
print('\nMinimum and Maximum Prices are =','(',df['Min_x0020_Price'].min(),',',df['Max_x0020_Price'].max(),')')
print('\nMost Demanding Commodity is =',df['Commodity'].value_counts().idxmax())
print('\nLeast Demanding Commodity is =',df['Commodity'].value_counts().idxmin())
# Out:
# Unique States in Dataset are = ['Himachal Pradesh' 'Jammu and Kashmir' 'Karnataka' 'Gujarat' 'Haryana'
#  'Chattisgarh' 'Goa' 'Andhra Pradesh' 'Bihar' 'Chandigarh' 'Kerala'
#  'Madhya Pradesh' 'Maharashtra' 'Rajasthan' 'Manipur' 'Meghalaya'
#  'Nagaland' 'NCT of Delhi' 'Odisha' 'Punjab' 'Pondicherry' 'Uttar Pradesh'
#  'Telangana' 'Tripura' 'Tamil Nadu' 'Uttrakhand' 'West Bengal']
#
# Most Dominating State = Uttar Pradesh
#
# Least Dominating State = Goa
#
# Minimum and Maximum Prices are = ( 1.0 , 1000000.0 )
#
# Most Demanding Commodity is = Onion
#
# Least Demanding Commodity is = Same/Savi

# %%
#To visualize the usage of states in the data,
df['State'].value_counts().plot(kind='bar',color=['#BE81F7','#2EFEC8','#58FAAC','#FFFF00','#F7BE81','#86B404'])
plt.title("Visualize the States in the data")
plt.xlabel("States")
plt.ylabel("Count of Values")
plt.show()

# %%
#To visualize the top 10 districts in the data
df['District'].value_counts().nlargest(10).plot(kind='bar',color=['#0080FF','#E1F5A9','#01DF01','#F7BE81'])
plt.title('Top 10 districts in the data')
plt.xlabel('District')
plt.ylabel('Value Count')
plt.show()

# %%
#To find the market that generated the most revenue,
df['Market_revenue']=df['Min_x0020_Price']+df['Max_x0020_Price']+df['Modal_x0020_Price']
label=['Nahan','Kollengode','Mumbai','Thodupuzha','Fish,Poultry & Egg Market, Gazipur','Pothencode','Shimoga','Yellapur','Siddapur','Palakkad']
df.groupby('Market')['Market_revenue'].sum().sort_values(ascending=False).head(10)\
.plot(kind='pie',labels=label,
    colors=['#81F7D8','#BCA9F5','#2EFE64','#FE2E2E','#FF0000'],
    autopct='%1.2f%%',shadow=True)
plt.title("Most Revenued to Market in the data")
plt.show()

# %%
df.head()
# Out:
#               State District        Market                Commodity Variety  \
# 0  Himachal Pradesh  Sirmore  Paonta Sahib                   Banana   Other
# 1  Himachal Pradesh  Sirmore  Paonta Sahib                 Capsicum   Other
# 2  Himachal Pradesh  Sirmore  Paonta Sahib  French Beans (Frasbean)   Other
# 3  Himachal Pradesh  Sirmore  Paonta Sahib                   Kinnow   Other
# 4  Himachal Pradesh  Sirmore  Paonta Sahib          Leafy Vegetable   Other
#
#   Arrival_Date  Min_x0020_Price  Max_x0020_Price  Modal_x0020_Price  \
# 0   23/02/2023           5000.0      6000.000000             5500.0
# 1   23/02/2023           2500.0      4000.000000             3000.0
# 2   23/02/2023           4000.0      5500.000000             5000.0
# 3   23/02/2023           4500.0      6000.000000             5000.0
# 4   23/02/2023           1000.0      4428.146716             1000.0
#
#    Market_revenue
# 0    16500.000000
# 1     9500.000000
# 2    14500.000000
# 3    15500.000000
# 4     6428.146716

# %%
#To visualize the distribution of maximum, minimum, and modal prices, you can create a histogram for each using the hist() function.
plt.figure(figsize=(12, 6))

# Histogram for Minimum Price
plt.hist(df['Min_x0020_Price'], bins=20, alpha=0.5, label='Min Price', color='blue')

# Histogram for Maximum Price
plt.hist(df['Max_x0020_Price'], bins=20, alpha=0.5, label='Max Price', color='orange')

# Histogram for Modal Price
plt.hist(df['Modal_x0020_Price'], bins=20, alpha=0.5, label='Modal Price', color='green')

plt.title('Distribution of Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
#Create scatter plot for min and modal price
df.plot.scatter(x='Min_x0020_Price', y='Modal_x0020_Price',color='red')
plt.xlabel('Min Price')
plt.ylabel('Modal Price')
plt.title('Relationship between Min Price and Modal Price')
plt.show()

# %%
# Find the Average price of the top 10 commodity in the data
avg_prices = df.groupby('Commodity')['Min_x0020_Price', 'Max_x0020_Price', 'Modal_x0020_Price'].mean()
avg_prices.head(10).style.background_gradient(cmap='tab20b')
# Out:
# <style type="text/css">
# #T_31295_row0_col0, #T_31295_row0_col1, #T_31295_row0_col2, #T_31295_row7_col0, #T_31295_row7_col1, #T_31295_row7_col2 {
#   background-color: #6b6ecf;
#   color: #f1f1f1;
# }
# #T_31295_row1_col0, #T_31295_row1_col1, #T_31295_row1_col2, #T_31295_row3_col0, #T_31295_row3_col1, #T_31295_row3_col2, #T_31295_row4_col0, #T_31295_row4_col1, #T_31295_row4_col2, #T_31295_row5_col0, #T_31295_row5_col1, #T_31295_row5_col2, #T_31295_row6_col0, #T_31295_row6_col1, #T_31295_row6_col2 {
#   background-color: #393b79;
#   color: #f1f1f1;
# }
# #T_31295_row2_col0, #T_31295_row2_col1, #T_31295_row2_col2 {
#   background-color: #de9ed6;
#   color: #000000;
# }
# #T_31295_row8_col0, #T_31295_row8_col1 {
#   background-color: #8c6d31;
#   color: #f1f1f1;
# }
# #T_31295_row8_col2 {
#   background-color: #bd9e39;
#   color: #f1f1f1;
# }
# #T_31295_row9_col0, #T_31295_row9_col1, #T_31295_row9_col2 {
#   background-color: #5254a3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_31295" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_31295_level0_col0" class="col_heading level0 col0" >Min_x0020_Price</th>
#       <th id="T_31295_level0_col1" class="col_heading level0 col1" >Max_x0020_Price</th>
#       <th id="T_31295_level0_col2" class="col_heading level0 col2" >Modal_x0020_Price</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Commodity</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_31295_level0_row0" class="row_heading level0 row0" >Ajwan</th>
#       <td id="T_31295_row0_col0" class="data row0 col0" >11000.000000</td>
#       <td id="T_31295_row0_col1" class="data row0 col1" >14130.000000</td>
#       <td id="T_31295_row0_col2" class="data row0 col2" >12337.500000</td>
#     </tr>
#     <tr>
#       <th id="T_31295_level0_row1" class="row_heading level0 row1" >Alasande Gram</th>
#       <td id="T_31295_row1_col0" class="data row1 col0" >5852.500000</td>
#       <td id="T_31295_row1_col1" class="data row1 col1" >6380.250000</td>
#       <td id="T_31295_row1_col2" class="data row1 col2" >6194.000000</td>
#     </tr>
#     <tr>
#       <th id="T_31295_level0_row2" class="row_heading level0 row2" >Almond(Badam)</th>
#       <td id="T_31295_row2_col0" class="data row2 col0" >70000.000000</td>
#       <td id="T_31295_row2_col1" class="data row2 col1" >80000.000000</td>
#       <td id="T_31295_row2_col2" class="data row2 col2" >75000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_31295_level0_row3" class="row_heading level0 row3" >Alsandikai</th>
#       <td id="T_31295_row3_col0" class="data row3 col0" >3700.000000</td>
#       <td id="T_31295_row3_col1" class="data row3 col1" >4100.000000</td>
#       <td id="T_31295_row3_col2" class="data row3 col2" >3900.000000</td>
#     </tr>
#     <tr>
#       <th id="T_31295_level0_row4" class="row_heading level0 row4" >Amaranthus</th>
#       <td id="T_31295_row4_col0" class="data row4 col0" >3561.290323</td>
#       <td id="T_31295_row4_col1" class="data row4 col1" >4102.580645</td>
#       <td id="T_31295_row4_col2" class="data row4 col2" >3802.903226</td>
#     </tr>
#     <tr>
#       <th id="T_31295_level0_row5" class="row_heading level0 row5" >Amla(Nelli Kai)</th>
#       <td id="T_31295_row5_col0" class="data row5 col0" >2868.181818</td>
#       <td id="T_31295_row5_col1" class="data row5 col1" >3540.909091</td>
#       <td id="T_31295_row5_col2" class="data row5 col2" >3218.181818</td>
#     </tr>
#     <tr>
#       <th id="T_31295_level0_row6" class="row_heading level0 row6" >Amphophalus</th>
#       <td id="T_31295_row6_col0" class="data row6 col0" >3450.000000</td>
#       <td id="T_31295_row6_col1" class="data row6 col1" >3825.000000</td>
#       <td id="T_31295_row6_col2" class="data row6 col2" >3606.250000</td>
#     </tr>
#     <tr>
#       <th id="T_31295_level0_row7" class="row_heading level0 row7" >Apple</th>
#       <td id="T_31295_row7_col0" class="data row7 col0" >9619.747423</td>
#       <td id="T_31295_row7_col1" class="data row7 col1" >11367.335808</td>
#       <td id="T_31295_row7_col2" class="data row7 col2" >10474.355670</td>
#     </tr>
#     <tr>
#       <th id="T_31295_level0_row8" class="row_heading level0 row8" >Arecanut(Betelnut/Supari)</th>
#       <td id="T_31295_row8_col0" class="data row8 col0" >30073.060000</td>
#       <td id="T_31295_row8_col1" class="data row8 col1" >37926.900000</td>
#       <td id="T_31295_row8_col2" class="data row8 col2" >35794.460000</td>
#     </tr>
#     <tr>
#       <th id="T_31295_level0_row9" class="row_heading level0 row9" >Arhar (Tur/Red Gram)(Whole)</th>
#       <td id="T_31295_row9_col0" class="data row9 col0" >6573.926829</td>
#       <td id="T_31295_row9_col1" class="data row9 col1" >7388.739837</td>
#       <td id="T_31295_row9_col2" class="data row9 col2" >7104.487805</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Create a pie chart to visualize the top 10 commoditys in the data
color=['#0080FF','#F79F81','#00BFFF','#3ADF00','#7401DF','#FF0040']
label=['Onion','Potato','Tomato','Brinjal','Green Chilli','Cauliflower','Cabbage','Wheat','Banana','Carrot']
df['Commodity'].value_counts().sort_values(ascending=False).head(10)\
.plot(kind='pie',labels=label,
    colors=color,
    autopct='%1.2f%%',
    shadow=True)
plt.title("Top 10 Commodity in the Data ")
plt.show()

# %%
# To Calculated the most Revenue generated states
df['Revenue']=df['Min_x0020_Price']*df['Modal_x0020_Price']
df.groupby('State')['Revenue'].sum().sort_values(ascending=False).head(10)\
.plot(kind='bar',title='Top 10 States Most Revenue generated',color=['#82FA58','#E1F5A9','#FA58AC','#DF013A','#4B8A08'])
plt.xlabel("State")
plt.ylabel("Sum of the Revenue")
plt.show()

# %% [markdown]
# # Observations
# #### From the analysis of the bar, pie, histogram, and scatter charts, several interesting insights can be observed:
#
# - Uttar Pradesh emerges as the most dominating state in the data, while Goa is the least dominating state.
# - Among the districts, Malappuram and Pune stand out as the dominant districts based on the bar chart.
# - The pie chart depicting market revenue reveals that Nahan generates the highest revenue, followed by Kollengode and Mumbai.
# - The scatter chart demonstrates a clear linear relationship between the minimum and maximum prices, indicating a strong correlation between these variables.
# - According to the pie chart, the dominating commodities are Onion, Potato, and Tomato, in that order. These commodities generate a significant portion of the overall market share.
#
# - When considering revenue, Himachal Pradesh emerges as the state with the highest revenue generation, followed by Kerala and Karnataka. These states demonstrate strong performance in terms of revenue generation in the given dataset

# %% [markdown]
# ## Another Questions asked from the data
# - To visualize the top 10 districts that provide Green Chillies, we can create a bar chart showing the districts on the x-axis and the quantity of Green Chillies on the y-axis.
#
# - To calculate the profit or loss of Onions with the current price on a state-wise basis, we can compare the current price with the purchase price or production cost. We can then create a bar chart to represent the profit or loss for each state.
#
# - Similarly, we can calculate the profit or loss of Apple production in different states by comparing the current price with the production cost. A bar chart can be used to visualize the profit or loss for each state.
#
# - To identify the top 10 states that provide Rice, we can create a bar chart with the states on the x-axis and the quantity of Rice on the y-axis.
#
# - For the top 10 districts that sold Rice at the maximum price, we can use a pie chart to represent the distribution of these districts.
#
# - To find the variety of Rice that was sold at the minimum prices, we can analyze the data and identify the variety with the lowest prices. We can then present this information, along with the corresponding districts or states, using suitable visualization techniques.

# %%
# Create a pie chart to Visualize Green Chilli produced the States
chilli=df[df['Commodity']=='Green Chilli']
label=['Uttar Pradesh','Kerala','West Bengal','Maharashtra','Haryana','Telangana','Himachal Pradesh','Karnataka','Madhya Pradesh','Gujart']
chilli['State'].value_counts().head(10).sort_values(ascending=False)\
.plot(kind='pie',labels=label,
    colors=['#58FAAC','#DF013A','#B40404','#61210B','#29088A'],
    autopct='%1.2f%%',
    shadow=True)
plt.title("Top 10 States produce the Greeen Chilli")
plt.show()

# %%
# Find the profit and loss states for the Onion Prices
current_maximum_price=2000
colors=['#82FA58','#013ADF','#D7DF01','#FA8258','#FF0080','#FA58AC']
onion=df[df['Commodity']=='Onion']
onion['onion_profit']=onion['Max_x0020_Price']-current_maximum_price
onion.groupby('State')['onion_profit'].sum()\
.plot(kind='bar',figsize=(8,6),title="Most Profit and loss gained states in onions",color=colors)
plt.xlabel("Price")
plt.ylabel("States")
plt.show()

# %%
#To calculate the most Profitalble states in Apple fruits sales with current_apple_price
current_apple_price=8225
apple_data=df[df['Commodity']=='Apple']
apple_data['Profit']=df['Min_x0020_Price']-current_apple_price
apple_data.groupby('State')['Profit'].sum().sort_values(ascending=False)\
.plot(kind='barh',title="Most profitable  state in Apple fruits",color=['#9A2EFE','#FA5858','#F7FE2E','#FA58AC','#0A1B2A','#01DF01'])
plt.xlabel("Price")
plt.ylabel("State")
plt.show()

# %%
# Maximum price to Produced the Rice in state wise
rice=df[df['Commodity']=='Rice']
colors=['#A9BCF5','#01DFD7','#5858FA','#08298A','#01DF74']
rice.groupby('State')['Max_x0020_Price'].mean().sort_values(ascending=False).plot(kind='bar',title='Top States Produce the Rice',color=colors)
plt.xlabel("States")
plt.ylabel("Average Maximum price")
plt.show()

# %%
rice=df[df['Commodity']=='Rice']
color=['#A9BCF5','#01DFD7','#5858FA','#08298A','#01DF74']
label=['Burdwan','Birbhum','Darjeeling','Bankura','Shimoga','Howrah','Gulbarga','Gautam Budh Nagar','Malappuram','Thane']
rice.groupby('District')['Max_x0020_Price'].sum().sort_values(ascending=False).head(10)\
.plot(kind='pie',labels=label,
    colors=color,
    autopct='%1.2f%%',
    shadow=True)
plt.title("Top 10 Distict get more maximum price for  the Rice ")
plt.show()

# %%
# Find the variety of the sold for the minimum prices
variety_min_price_sum = rice.groupby(['State', 'Variety'])['Min_x0020_Price'].sum().reset_index()
plt.figure(figsize=(8, 6))
sns.barplot(x=variety_min_price_sum['Variety'], y=variety_min_price_sum['Min_x0020_Price'])
plt.xlabel('Variety')
plt.ylabel('Sum of Minimum Price')
plt.title('Sum of Minimum Price by Variety and State')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Observations:
# - Uttar Pradesh is the top state in terms of Green Chilli production, followed by Kerala and West Bengal.
# - Kerala and Maharashtra are the states that have gained more profit with Onion at the current prices, while Uttar Pradesh has experienced losses due to high prices.
# - Himachal Pradesh and Kerala have earned more profit with Apple fruits at the current prices, while Uttar Pradesh and Punjab have faced losses due to lower prices.
# - Karnataka, Maharashtra, and Kerala are the top states producing high-priced Rice.
# - 18% of the Rice revenue is generated from Burdwan district, while 14% of the revenue is generated from Birbhum.
# - Grade-3 and common varieties of Rice are sold at lower prices compared to other varieties.

# %% [markdown]
# ## Another Question asked from data
# - In the dataframe for Himachal Pradesh, we can find the commodity with the highest average price.
# - Similarly, in the dataframe for Telangana state, we can identify the commodity with the highest average price.
# - We can determine the available commodities in Andhra Pradesh.
# - By analyzing the data for Andhra Pradesh, we can calculate the revenue generated in each district.
# - We can identify the top 10 markets with the average minimum price.
# - We can determine which states are the largest producers of Banana items.
# - To find the average maximum price of the top 10 districts.

# %%
# Top 10 Commodity mininmum price in the Himachal Pradesh
Himachal=df[df['State']=='Himachal Pradesh']
Himachal.groupby('Commodity')['Max_x0020_Price'].mean().head(10).sort_values(ascending=False)\
.plot(kind='bar',title="Top 10 Commodity in the Himachal Pradesh",color=['#CEF6CE','#00FFBF','#FE9A2E','#DF013A','#F8E0E6'])
plt.xlabel("Commodity")
plt.ylabel("Average maximum price of the Commodity")
plt.show()

# %%
# Demanding Commodity in the Telanagana
telangana=df[df['State']=='Telangana']
telangana.groupby('Commodity')['Max_x0020_Price'].sum().head(10).sort_values(ascending=False)\
.plot(kind='bar',title='Top 10 Demanading Commodity in the data',color=['#0B6138','#DF7401','#FE2EF7','#F6CED8','#7401DF'])
plt.xlabel("Commodity")
plt.ylabel("Sum of the Maximum price")
plt.show()

# %%
# Find the top 10 Minimum and maximum values of the commodity with minimum prices
commodity_stats = df.groupby('Commodity')['Min_x0020_Price'].agg(['min', 'max'])
commodity_stats.head(10).style.background_gradient(cmap='nipy_spectral_r')
# Out:
# <style type="text/css">
# #T_2bfcf_row0_col0 {
#   background-color: #ee0000;
#   color: #f1f1f1;
# }
# #T_2bfcf_row0_col1, #T_2bfcf_row6_col0, #T_2bfcf_row9_col1 {
#   background-color: #cc9c9c;
#   color: #f1f1f1;
# }
# #T_2bfcf_row1_col0 {
#   background-color: #cc0000;
#   color: #f1f1f1;
# }
# #T_2bfcf_row1_col1, #T_2bfcf_row4_col0, #T_2bfcf_row5_col1 {
#   background-color: #ccbcbc;
#   color: #000000;
# }
# #T_2bfcf_row2_col0, #T_2bfcf_row7_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_2bfcf_row2_col1 {
#   background-color: #e40000;
#   color: #f1f1f1;
# }
# #T_2bfcf_row3_col0 {
#   background-color: #cc1c1c;
#   color: #f1f1f1;
# }
# #T_2bfcf_row3_col1, #T_2bfcf_row5_col0, #T_2bfcf_row6_col1, #T_2bfcf_row7_col0 {
#   background-color: #cccccc;
#   color: #000000;
# }
# #T_2bfcf_row4_col1 {
#   background-color: #cc6c6c;
#   color: #f1f1f1;
# }
# #T_2bfcf_row8_col0 {
#   background-color: #d30000;
#   color: #f1f1f1;
# }
# #T_2bfcf_row8_col1 {
#   background-color: #d70000;
#   color: #f1f1f1;
# }
# #T_2bfcf_row9_col0 {
#   background-color: #cc8c8c;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2bfcf" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2bfcf_level0_col0" class="col_heading level0 col0" >min</th>
#       <th id="T_2bfcf_level0_col1" class="col_heading level0 col1" >max</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Commodity</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2bfcf_level0_row0" class="row_heading level0 row0" >Ajwan</th>
#       <td id="T_2bfcf_row0_col0" class="data row0 col0" >9500.000000</td>
#       <td id="T_2bfcf_row0_col1" class="data row0 col1" >12500.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2bfcf_level0_row1" class="row_heading level0 row1" >Alasande Gram</th>
#       <td id="T_2bfcf_row1_col0" class="data row1 col0" >4400.000000</td>
#       <td id="T_2bfcf_row1_col1" class="data row1 col1" >6535.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2bfcf_level0_row2" class="row_heading level0 row2" >Almond(Badam)</th>
#       <td id="T_2bfcf_row2_col0" class="data row2 col0" >70000.000000</td>
#       <td id="T_2bfcf_row2_col1" class="data row2 col1" >70000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2bfcf_level0_row3" class="row_heading level0 row3" >Alsandikai</th>
#       <td id="T_2bfcf_row3_col0" class="data row3 col0" >3700.000000</td>
#       <td id="T_2bfcf_row3_col1" class="data row3 col1" >3700.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2bfcf_level0_row4" class="row_heading level0 row4" >Amaranthus</th>
#       <td id="T_2bfcf_row4_col0" class="data row4 col0" >1200.000000</td>
#       <td id="T_2bfcf_row4_col1" class="data row4 col1" >20000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2bfcf_level0_row5" class="row_heading level0 row5" >Amla(Nelli Kai)</th>
#       <td id="T_2bfcf_row5_col0" class="data row5 col0" >800.000000</td>
#       <td id="T_2bfcf_row5_col1" class="data row5 col1" >6100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2bfcf_level0_row6" class="row_heading level0 row6" >Amphophalus</th>
#       <td id="T_2bfcf_row6_col0" class="data row6 col0" >1600.000000</td>
#       <td id="T_2bfcf_row6_col1" class="data row6 col1" >5000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2bfcf_level0_row7" class="row_heading level0 row7" >Apple</th>
#       <td id="T_2bfcf_row7_col0" class="data row7 col0" >700.000000</td>
#       <td id="T_2bfcf_row7_col1" class="data row7 col1" >600000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2bfcf_level0_row8" class="row_heading level0 row8" >Arecanut(Betelnut/Supari)</th>
#       <td id="T_2bfcf_row8_col0" class="data row8 col0" >5786.000000</td>
#       <td id="T_2bfcf_row8_col1" class="data row8 col1" >52629.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2bfcf_level0_row9" class="row_heading level0 row9" >Arhar (Tur/Red Gram)(Whole)</th>
#       <td id="T_2bfcf_row9_col0" class="data row9 col0" >2040.000000</td>
#       <td id="T_2bfcf_row9_col1" class="data row9 col1" >11200.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Create pie chart to understand the Commodity in Andhra Pradesh
andhra_pradesh=df[df['State']=='Andhra Pradesh']
andhra_pradesh['Commodity'].value_counts().sort_values(ascending=False)\
.plot(kind='pie',labels=['Tomato','Gur(Jaggery)','Dry Chillies','Paddy(Dhan)(Common)','Turmeric','Lemon','Black Gram (Urd Beans)(Whole)','Jowar(Sorghum)'],
    colors=['#CC2EFA','#58FAD0','#FE2E2E','#81DAF5','#DF0101'],
    autopct='%1.2f%%',
    shadow=True)
plt.title("Andhra Pradesh Commodity in the data")
plt.show()

# %%
# Create a pie chart to find the District wise revenue generate in the andhra Pradesh
andhra_pradesh['Andhra_Revenue']=andhra_pradesh['Min_x0020_Price']+andhra_pradesh['Max_x0020_Price']+andhra_pradesh['Modal_x0020_Price']
label=['Guntur','Visakhapatnam','West Godavari','Chittor','East Godavari','Kurnool']
color=['#58FA58','#FF4000','#688A08','#FF0040','#F6CED8','#A9F5F2']
andhra_pradesh.groupby('District')['Andhra_Revenue'].sum().sort_values(ascending=False)\
.plot(kind='pie',labels=label,
    colors=color,
    autopct='%1.2f%%',
    shadow=True)
plt.title("Andhra Pradesh District wise Revenue")
plt.show()

# %%
market_price_range = df.groupby('Market')['Min_x0020_Price', 'Max_x0020_Price'].apply(lambda x: x.max() - x.min())
market_price_range.head(10).style.background_gradient(cmap='twilight_shifted')
# Out:
# <style type="text/css">
# #T_2796d_row0_col0, #T_2796d_row0_col1, #T_2796d_row4_col0, #T_2796d_row4_col1 {
#   background-color: #301437;
#   color: #f1f1f1;
# }
# #T_2796d_row1_col0 {
#   background-color: #3c114b;
#   color: #f1f1f1;
# }
# #T_2796d_row1_col1 {
#   background-color: #3b114a;
#   color: #f1f1f1;
# }
# #T_2796d_row2_col0 {
#   background-color: #ded3d4;
#   color: #000000;
# }
# #T_2796d_row2_col1 {
#   background-color: #a03d50;
#   color: #f1f1f1;
# }
# #T_2796d_row3_col0 {
#   background-color: #3e113c;
#   color: #f1f1f1;
# }
# #T_2796d_row3_col1 {
#   background-color: #61184b;
#   color: #f1f1f1;
# }
# #T_2796d_row5_col0 {
#   background-color: #6989be;
#   color: #f1f1f1;
# }
# #T_2796d_row5_col1 {
#   background-color: #657fbd;
#   color: #f1f1f1;
# }
# #T_2796d_row6_col0, #T_2796d_row6_col1 {
#   background-color: #2f1436;
#   color: #f1f1f1;
# }
# #T_2796d_row7_col0 {
#   background-color: #c6876b;
#   color: #f1f1f1;
# }
# #T_2796d_row7_col1 {
#   background-color: #cca287;
#   color: #f1f1f1;
# }
# #T_2796d_row8_col0 {
#   background-color: #541e7e;
#   color: #f1f1f1;
# }
# #T_2796d_row8_col1 {
#   background-color: #511b77;
#   color: #f1f1f1;
# }
# #T_2796d_row9_col0 {
#   background-color: #87abc4;
#   color: #f1f1f1;
# }
# #T_2796d_row9_col1 {
#   background-color: #97b7c7;
#   color: #000000;
# }
# </style>
# <table id="T_2796d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2796d_level0_col0" class="col_heading level0 col0" >Min_x0020_Price</th>
#       <th id="T_2796d_level0_col1" class="col_heading level0 col1" >Max_x0020_Price</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Market</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2796d_level0_row0" class="row_heading level0 row0" >Aarni</th>
#       <td id="T_2796d_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_2796d_row0_col1" class="data row0 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2796d_level0_row1" class="row_heading level0 row1" >Abhanpur</th>
#       <td id="T_2796d_row1_col0" class="data row1 col0" >575.000000</td>
#       <td id="T_2796d_row1_col1" class="data row1 col1" >570.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2796d_level0_row2" class="row_heading level0 row2" >Abohar</th>
#       <td id="T_2796d_row2_col0" class="data row2 col0" >7450.000000</td>
#       <td id="T_2796d_row2_col1" class="data row2 col1" >11950.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2796d_level0_row3" class="row_heading level0 row3" >Achalda</th>
#       <td id="T_2796d_row3_col0" class="data row3 col0" >13450.000000</td>
#       <td id="T_2796d_row3_col1" class="data row3 col1" >13550.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2796d_level0_row4" class="row_heading level0 row4" >Adilabad</th>
#       <td id="T_2796d_row4_col0" class="data row4 col0" >0.000000</td>
#       <td id="T_2796d_row4_col1" class="data row4 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2796d_level0_row5" class="row_heading level0 row5" >Adilabad(Rythu Bazar)</th>
#       <td id="T_2796d_row5_col0" class="data row5 col0" >4000.000000</td>
#       <td id="T_2796d_row5_col1" class="data row5 col1" >4000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2796d_level0_row6" class="row_heading level0 row6" >Adimali</th>
#       <td id="T_2796d_row6_col0" class="data row6 col0" >14000.000000</td>
#       <td id="T_2796d_row6_col1" class="data row6 col1" >15000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2796d_level0_row7" class="row_heading level0 row7" >Agra</th>
#       <td id="T_2796d_row7_col0" class="data row7 col0" >9370.000000</td>
#       <td id="T_2796d_row7_col1" class="data row7 col1" >9400.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2796d_level0_row8" class="row_heading level0 row8" >Ahmedgarh</th>
#       <td id="T_2796d_row8_col0" class="data row8 col0" >1400.000000</td>
#       <td id="T_2796d_row8_col1" class="data row8 col1" >1400.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2796d_level0_row9" class="row_heading level0 row9" >Ahmedpur</th>
#       <td id="T_2796d_row9_col0" class="data row9 col0" >4950.000000</td>
#       <td id="T_2796d_row9_col1" class="data row9 col1" >5701.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Group data by 'State' and analyze aggregated information
state_stats = df.groupby('State').agg({'Min_x0020_Price': ['mean', 'median', 'max', 'min']})
state_stats.style.background_gradient(cmap='inferno')
# Out:
# <style type="text/css">
# #T_10fe7_row0_col0 {
#   background-color: #0d0829;
#   color: #f1f1f1;
# }
# #T_10fe7_row0_col1, #T_10fe7_row21_col0 {
#   background-color: #0e092b;
#   color: #f1f1f1;
# }
# #T_10fe7_row0_col2, #T_10fe7_row1_col0, #T_10fe7_row1_col2, #T_10fe7_row2_col2, #T_10fe7_row6_col2, #T_10fe7_row6_col3, #T_10fe7_row10_col3, #T_10fe7_row11_col2, #T_10fe7_row12_col3, #T_10fe7_row15_col3, #T_10fe7_row16_col2, #T_10fe7_row18_col2, #T_10fe7_row19_col3, #T_10fe7_row22_col3, #T_10fe7_row25_col0, #T_10fe7_row25_col1, #T_10fe7_row25_col2 {
#   background-color: #000004;
#   color: #f1f1f1;
# }
# #T_10fe7_row0_col3, #T_10fe7_row3_col0, #T_10fe7_row3_col1 {
#   background-color: #02020c;
#   color: #f1f1f1;
# }
# #T_10fe7_row1_col1, #T_10fe7_row2_col3, #T_10fe7_row3_col3, #T_10fe7_row5_col3, #T_10fe7_row8_col2, #T_10fe7_row9_col3, #T_10fe7_row11_col3, #T_10fe7_row19_col2, #T_10fe7_row20_col3, #T_10fe7_row23_col3, #T_10fe7_row24_col3, #T_10fe7_row25_col3 {
#   background-color: #010005;
#   color: #f1f1f1;
# }
# #T_10fe7_row1_col3, #T_10fe7_row2_col0, #T_10fe7_row3_col2, #T_10fe7_row8_col3, #T_10fe7_row17_col3, #T_10fe7_row21_col2, #T_10fe7_row26_col3 {
#   background-color: #010106;
#   color: #f1f1f1;
# }
# #T_10fe7_row2_col1, #T_10fe7_row6_col0, #T_10fe7_row6_col1, #T_10fe7_row19_col1, #T_10fe7_row22_col2 {
#   background-color: #02010a;
#   color: #f1f1f1;
# }
# #T_10fe7_row4_col0, #T_10fe7_row4_col1, #T_10fe7_row4_col3, #T_10fe7_row7_col2 {
#   background-color: #fcffa4;
#   color: #000000;
# }
# #T_10fe7_row4_col2, #T_10fe7_row11_col0, #T_10fe7_row11_col1, #T_10fe7_row12_col1, #T_10fe7_row17_col1, #T_10fe7_row18_col1, #T_10fe7_row20_col1, #T_10fe7_row21_col3, #T_10fe7_row22_col1, #T_10fe7_row23_col1 {
#   background-color: #040312;
#   color: #f1f1f1;
# }
# #T_10fe7_row5_col0, #T_10fe7_row5_col1 {
#   background-color: #150b37;
#   color: #f1f1f1;
# }
# #T_10fe7_row5_col2, #T_10fe7_row13_col2, #T_10fe7_row13_col3, #T_10fe7_row20_col2, #T_10fe7_row26_col1, #T_10fe7_row26_col2 {
#   background-color: #02020e;
#   color: #f1f1f1;
# }
# #T_10fe7_row7_col0 {
#   background-color: #390963;
#   color: #f1f1f1;
# }
# #T_10fe7_row7_col1, #T_10fe7_row8_col1, #T_10fe7_row14_col1 {
#   background-color: #0b0724;
#   color: #f1f1f1;
# }
# #T_10fe7_row7_col3, #T_10fe7_row19_col0 {
#   background-color: #010108;
#   color: #f1f1f1;
# }
# #T_10fe7_row8_col0, #T_10fe7_row9_col2, #T_10fe7_row15_col2 {
#   background-color: #0a0722;
#   color: #f1f1f1;
# }
# #T_10fe7_row9_col0, #T_10fe7_row10_col0 {
#   background-color: #290b55;
#   color: #f1f1f1;
# }
# #T_10fe7_row9_col1, #T_10fe7_row18_col0 {
#   background-color: #09061f;
#   color: #f1f1f1;
# }
# #T_10fe7_row10_col1 {
#   background-color: #10092d;
#   color: #f1f1f1;
# }
# #T_10fe7_row10_col2 {
#   background-color: #69166e;
#   color: #f1f1f1;
# }
# #T_10fe7_row12_col0 {
#   background-color: #08051d;
#   color: #f1f1f1;
# }
# #T_10fe7_row12_col2 {
#   background-color: #280b53;
#   color: #f1f1f1;
# }
# #T_10fe7_row13_col0 {
#   background-color: #3b0964;
#   color: #f1f1f1;
# }
# #T_10fe7_row13_col1, #T_10fe7_row16_col3 {
#   background-color: #110a30;
#   color: #f1f1f1;
# }
# #T_10fe7_row14_col0 {
#   background-color: #360961;
#   color: #f1f1f1;
# }
# #T_10fe7_row14_col2, #T_10fe7_row14_col3, #T_10fe7_row20_col0, #T_10fe7_row26_col0 {
#   background-color: #050417;
#   color: #f1f1f1;
# }
# #T_10fe7_row15_col0 {
#   background-color: #9a2865;
#   color: #f1f1f1;
# }
# #T_10fe7_row15_col1 {
#   background-color: #5a116e;
#   color: #f1f1f1;
# }
# #T_10fe7_row16_col0 {
#   background-color: #190c3e;
#   color: #f1f1f1;
# }
# #T_10fe7_row16_col1 {
#   background-color: #2d0b59;
#   color: #f1f1f1;
# }
# #T_10fe7_row17_col0, #T_10fe7_row17_col2, #T_10fe7_row23_col2 {
#   background-color: #030210;
#   color: #f1f1f1;
# }
# #T_10fe7_row18_col3 {
#   background-color: #07051b;
#   color: #f1f1f1;
# }
# #T_10fe7_row21_col1, #T_10fe7_row24_col0, #T_10fe7_row24_col2 {
#   background-color: #060419;
#   color: #f1f1f1;
# }
# #T_10fe7_row22_col0, #T_10fe7_row24_col1 {
#   background-color: #040314;
#   color: #f1f1f1;
# }
# #T_10fe7_row23_col0 {
#   background-color: #180c3c;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_10fe7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_10fe7_level0_col0" class="col_heading level0 col0" colspan="4">Min_x0020_Price</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_10fe7_level1_col0" class="col_heading level1 col0" >mean</th>
#       <th id="T_10fe7_level1_col1" class="col_heading level1 col1" >median</th>
#       <th id="T_10fe7_level1_col2" class="col_heading level1 col2" >max</th>
#       <th id="T_10fe7_level1_col3" class="col_heading level1 col3" >min</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >State</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_10fe7_level0_row0" class="row_heading level0 row0" >Andhra Pradesh</th>
#       <td id="T_10fe7_row0_col0" class="data row0 col0" >3795.882353</td>
#       <td id="T_10fe7_row0_col1" class="data row0 col1" >3360.000000</td>
#       <td id="T_10fe7_row0_col2" class="data row0 col2" >8000.000000</td>
#       <td id="T_10fe7_row0_col3" class="data row0 col3" >640.000000</td>
#     </tr>
#     <tr>
#       <th id="T_10fe7_level0_row1" class="row_heading level0 row1" >Bihar</th>
#       <td id="T_10fe7_row1_col0" class="data row1 col0" >1640.625000</td>
#       <td id="T_10fe7_row1_col1" class="data row1 col1" >1200.000000</td>
#       <td id="T_10fe7_row1_col2" class="data row1 col2" >6000.000000</td>
#       <td id="T_10fe7_row1_col3" class="data row1 col3" >350.000000</td>
#     </tr>
#     <tr>
#       <th id="T_10fe7_level0_row2" class="row_heading level0 row2" >Chandigarh</th>
#       <td id="T_10fe7_row2_col0" class="data row2 col0" >1935.714286</td>
#       <td id="T_10fe7_row2_col1" class="data row2 col1" >1500.000000</td>
#       <td id="T_10fe7_row2_col2" class="data row2 col2" >6000.000000</td>
#       <td id="T_10fe7_row2_col3" class="data row2 col3" >200.000000</td>
#     </tr>
#     <tr>
#       <th id="T_10fe7_level0_row3" class="row_heading level0 row3" >Chattisgarh</th>
#       <td id="T_10fe7_row3_col0" class="data row3 col0" >2310.966102</td>
#       <td id="T_10fe7_row3_col1" class="data row3 col1" >1627.500000</td>
#       <td id="T_10fe7_row3_col2" class="data row3 col2" >13000.000000</td>
#       <td id="T_10fe7_row3_col3" class="data row3 col3" >200.000000</td>
#     </tr>
#     <tr>
#       <th id="T_10fe7_level0_row4" class="row_heading level0 row4" >Goa</th>
#       <td id="T_10fe7_row4_col0" class="data row4 col0" >31750.000000</td>
#       <td id="T_10fe7_row4_col1" class="data row4 col1" >31750.000000</td>
#       <td id="T_10fe7_row4_col2" class="data row4 col2" >33000.000000</td>
#       <td id="T_10fe7_row4_col3" class="data row4 col3" >30500.000000</td>
#     </tr>
#     <tr>
#       <th id="T_10fe7_level0_row5" class="row_heading level0 row5" >Gujarat</th>
#       <td id="T_10fe7_row5_col0" class="data row5 col0" >4566.186253</td>
#       <td id="T_10fe7_row5_col1" class="data row5 col1" >4000.000000</td>
#       <td id="T_10fe7_row5_col2" class="data row5 col2" >25500.000000</td>
#       <td id="T_10fe7_row5_col3" class="data row5 col3" >130.000000</td>
#     </tr>
#     <tr>
#       <th id="T_10fe7_level0_row6" class="row_heading level0 row6" >Haryana</th>
#       <td id="T_10fe7_row6_col0" class="data row6 col0" >2173.648753</td>
#       <td id="T_10fe7_row6_col1" class="data row6 col1" >1500.000000</td>
#       <td id="T_10fe7_row6_col2" class="data row6 col2" >9000.000000</td>
#       <td id="T_10fe7_row6_col3" class="data row6 col3" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_10fe7_level0_row7" class="row_heading level0 row7" >Himachal Pradesh</th>
#       <td id="T_10fe7_row7_col0" class="data row7 col0" >7099.007444</td>
#       <td id="T_10fe7_row7_col1" class="data row7 col1" >3000.000000</td>
#       <td id="T_10fe7_row7_col2" class="data row7 col2" >800000.000000</td>
#       <td id="T_10fe7_row7_col3" class="data row7 col3" >400.000000</td>
#     </tr>
#     <tr>

# %%
# Creat a bar chart to find the top 10 market with minimum price
df.groupby('Market')['Min_x0020_Price'].mean().nlargest(10).sort_values(ascending=False)\
.plot(kind='bar',title="Top 10 Markets with Average Minimum prices",figsize=(8,6),color=['#2EFEC8','#BEF781','#58FAAC','#64FE2E','#FE2E9A'])
plt.xlabel("Market")
plt.ylabel("Average Minimum price")
plt.show()

# %%
# To calcualte the Banana price with state wise using the grouby function
# Create a data frame with banana
banana=df[df['Commodity']=='Banana']
#Grouby the states with Minimumprice
sum_of_banana_prices_with_state_wise=banana.groupby('State')['Min_x0020_Price'].sum()
sum_of_banana_prices_with_state_wise.sort_values(ascending=False)\
.plot(kind='bar',title="States with Most amount earning with Banana",figsize=(8,6),color=['#00FFBF','#01DF01','#FAAC58','#FA58AC'])
plt.xlabel("State")
plt.ylabel("Sum of the Banana Minimumprice")
plt.show()

# %%
# What are the top 10 distric with  average Min_price
df.groupby('District')['Min_x0020_Price'].mean().head(10).sort_values(ascending=False)\
.plot(kind='bar',title='Top 10 District with Average minimum price',figsize=(8,6),color=['#81DAF5','#ACFA58','#64FE2E','#FA58AC','#D0A9F5'])
plt.xlabel("District")
plt.ylabel("Averages Minimum price")
plt.show()

# %% [markdown]
# ## Observations:
# - From the above charts, we have observed several insights in the data.
# - In Himachal Pradesh, Apple is the most sold commodity with a high average minimum price, followed by Ladies Finger.
# - In Telangana, Apple is also the most sold commodity with a high average minimum price, followed by Ladies Finger.
# - 18% of the commodities available in Andhra Pradesh are Tomato, Gur, and Dry Chillies.
# - Guntur generates 72% of the revenue in Andhra Pradesh, while Visakhapatnam contributes 10% of the revenue.
# - Nahan Market has the highest average prices in the data, followed by Kollengode.
# - Kerala and Uttar Pradesh are both states that produce commodities with higher average minimum prices compared to others.
# - Amaravati is the district with the highest average prices in the data, followed by Adilabad.

# %%
#Some Sample Questions asked for the data
state_with_highest_min_price = df.loc[df['Min_x0020_Price'].idxmax(), 'State']
state_with_lowest_min_price = df.loc[df['Min_x0020_Price'].idxmin(), 'State']
print("State with the highest minimum price:", state_with_highest_min_price)
print("State with the lowest minimum price:", state_with_lowest_min_price)
district_with_highest_min_price = df.loc[df['Max_x0020_Price'].idxmax(), 'District']
district_with_lowest_min_price = df.loc[df['Max_x0020_Price'].idxmin(), 'District']
print("District with the highest minimum price:", district_with_highest_min_price)
print("District with the lowest minimum price:", district_with_lowest_min_price)
commodity_with_highest_min_price = df.loc[df['Max_x0020_Price'].idxmax(), 'Commodity']
commodity_with_lowest_min_price = df.loc[df['Max_x0020_Price'].idxmin(), 'Commodity']
print("Commodity with the highest minimum price:", commodity_with_highest_min_price)
print("Commodity with the lowest minimum price:", commodity_with_lowest_min_price)
# Out:
# State with the highest minimum price: Himachal Pradesh
# State with the lowest minimum price: Maharashtra
# District with the highest minimum price: Sirmore
# District with the lowest minimum price: Sholapur
# Commodity with the highest minimum price: Grapes
# Commodity with the lowest minimum price: Lime

# %%
#Create a bar chart to understand the Which states have the highest minimum price
df.groupby('State')['Min_x0020_Price'].sum().sort_values(ascending=False)\
.plot(kind='bar',title="The Sum of the Minimum price with State wise",figsize=(8,6),color=['#D0FA58','#81F7BE','#9AFE2E','#088A29','#01A9DB'])
plt.xlabel("States")
plt.ylabel("Sum of the Minimum price")
plt.show()

# %%
# Created bar chart to find the Most revenue geneted from the chilli varietys
chilli=df[df['Commodity']=='Green Chilli']
chilli.groupby('Variety')['Revenue'].sum().sort_values(ascending=False)\
.plot(kind='bar',title="Revenue Generated from the green chillies",figsize=(8,6),color=['#088A29','#01A9DB'])
plt.xlabel("Varietys")
plt.ylabel("Sum of the Revenue generted from the each variety")
plt.show()

# %%
# To Visualize the Revenue from the each variety of the tomato
tomato=df[df['Commodity']=='Tomato']
label=['Deshi','Local','Local','Other','Sankar','Tomato']
color=['#58FAAC','#04B404','#FF4000','#8000FF','#81BEF7']
tomato.groupby('Variety')['Revenue'].sum().sort_values(ascending=False)\
.plot(kind='pie',labels=label,
    colors=color,
    autopct='%1.2f%%',
    shadow=True)
plt.title("Variety wise revenue generated from the tomato")
plt.show()

# %% [markdown]
# ## Observations:
# - Uttar Pradesh and Kerala have the highest sum of minimum prices in the data.
# - Green Chillies generate more revenue compared to other chilli varieties.
# - In the case of Tomatoes, 73% of the revenue is generated by the Desi variety, while the Local variety contributes only 15% of the revenue.
